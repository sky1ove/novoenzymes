# %% [markdown]
# # 1. Original

# %% [markdown]
# The original training csv is updated, the corrected csv can be found here https://www.kaggle.com/code/dschettler8845/novo-esp-how-to-use-updated-training-file

# %% [markdown]
# It contains mutated protein sequence, pH, data source, tm
#
# 28,981 lines

# %% [markdown]
# ![image.png](attachment:f8199347-58fb-40d5-954a-3bcbc5b7e0d2.png)

# %% [markdown]
# # 2. with/without WT sequence

# %% [markdown]
# https://www.kaggle.com/code/roberthatch/novo-train-data-contains-wildtype-groups
#
# add wildtype sequence, and group them to with WT (4195) and without WT (24786)
#
# 4195 + 24,786 = 28,981 (original)

# %% [markdown]
# **Without WT(24,786)** , x is length, all groups' value is -1 (as they are not grouped)

# %% [markdown]
# ![image.png](attachment:cc8db6ee-4ba7-4294-9b17-5e4d7ebc8821.png)

# %% [markdown]
# **With WT (4195)**, group number from 0 to 77

# %% [markdown]
# ![image.png](attachment:8b1163d3-03b0-455b-aa4f-60701ae4f1a4.png)

# %% [markdown]
# # 3. Add mut info and dTm (tm - group mean)

# %% [markdown]
# https://www.kaggle.com/code/cdeotte/xgboost-5000-mutations-200-pdb-files-lb-0-410/notebook kaggle_train.csv
#
# add dTm = tm - groupby('group').tm.transform('mean')
#
# **Reduced to 1737 lines**

# %% [markdown]
# ![image.png](attachment:6451f893-c883-44ed-9df0-7ae9ba80ec38.png)

# %% [markdown]
# # External data

# %% [markdown]
# Jin yuan Sun, with mutation info, and ddG (notice there's no temperature)
#
# **train.csv 3839 lines**

# %% [markdown]
# https://www.kaggle.com/code/cdeotte/xgboost-5000-mutations-200-pdb-files-lb-0-410/data
# downloaded_csv --> train, test, and tm

# %% [markdown]
# ![image.png](attachment:8043aab8-e8c0-4d95-bf7a-42e84a387e23.png)

# %% [markdown]
# **test.csv 259 lines (without tm info)**

# %% [markdown]
# ![image.png](attachment:15b1bf01-62db-49db-be88-2381f5449566.png)

# %% [markdown]
# **tm.csv 998 lines (with temperature info)**

# %% [markdown]
# ![image.png](attachment:e1e6adfa-5cb3-47d5-9e86-644dbfda1088.png)

# %% [markdown]
# ### 14656 NESP

# %% [markdown]
# https://www.kaggle.com/code/vslaykovsky/14656-unique-mutations-voxel-features-pdbs/notebook
#
# 14656 lines, has mut info, but no WT seq

# %% [markdown]
# ![image.png](attachment:0462187f-5666-4886-a456-ae376249d6e1.png)
